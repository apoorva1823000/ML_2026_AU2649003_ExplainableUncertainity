# %%
print('Hello')
# Out:
# Hello

# %%
conda create -n gee_env python=3.9
conda activate gee_env
# Out:
#   Cell In[3], line 1
#     conda create -n gee_env python=3.9
#           ^
# SyntaxError: invalid syntax
